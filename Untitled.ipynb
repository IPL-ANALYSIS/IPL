# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Matches=pd.read_csv("C:\\Users\\saide\\Desktop\\Capstone Project\\ipldata\\matches.csv")

# %%
Matches.head()
# Out:
#    id  season        city       date                  team1  \
# 0   1    2008   Bangalore  4/18/2008  Kolkata Knight Riders
# 1   2    2008  Chandigarh  4/19/2008    Chennai Super Kings
# 2   3    2008       Delhi  4/19/2008       Rajasthan Royals
# 3   4    2008      Mumbai  4/20/2008         Mumbai Indians
# 4   5    2008     Kolkata  4/20/2008        Deccan Chargers
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4        Kolkata Knight Riders              Deccan Chargers           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0        Kolkata Knight Riders          140
# ...

# %%
Matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 577 entries, 0 to 576
# Data columns (total 15 columns):
# id                 577 non-null int64
# season             577 non-null int64
# city               570 non-null object
# date               577 non-null object
# team1              577 non-null object
# team2              577 non-null object
# toss_winner        577 non-null object
# toss_decision      577 non-null object
# result             577 non-null object
# dl_applied         577 non-null int64
# winner             574 non-null object
# win_by_runs        577 non-null int64
# win_by_wickets     577 non-null int64
# player_of_match    574 non-null object
# venue              577 non-null object
# dtypes: int64(5), object(10)
# memory usage: 67.7+ KB

# %%
Matches[pd.isnull(Matches['winner'])]
# Out:
#       id  season       city       date                        team1  \
# 241  242    2011      Delhi  5/21/2011             Delhi Daredevils
# 486  487    2015  Bangalore  4/29/2015  Royal Challengers Bangalore
# 511  512    2015  Bangalore  5/17/2015             Delhi Daredevils
#
#                            team2                  toss_winner toss_decision  \
# 241                Pune Warriors             Delhi Daredevils           bat
# 486             Rajasthan Royals             Rajasthan Royals         field
# 511  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#         result  dl_applied winner  win_by_runs  win_by_wickets  \
# 241  no result           0    NaN            0               0
# 486  no result           0    NaN            0               0
# 511  no result           0    NaN            0               0
#
#     player_of_match                  venue
# 241             NaN       Feroz Shah Kotla
# ...

# %%
Matches['winner'].fillna('Draw', inplace=True)

# %%
Matches.iloc[241]
# Out:
# id                              242
# season                         2011
# city                          Delhi
# date                      5/21/2011
# team1              Delhi Daredevils
# team2                 Pune Warriors
# toss_winner        Delhi Daredevils
# toss_decision                   bat
# result                    no result
# dl_applied                        0
# winner                         Draw
# win_by_runs                       0
# win_by_wickets                    0
# player_of_match                 NaN
# venue              Feroz Shah Kotla
# Name: 241, dtype: object

# %% [raw]
#  Conver String type variable to Float.

# %%
Matches.replace(['Deccan Chargers','Delhi Daredevils','Pune Warriors','Rising Pune Supergiants'],['Sunrisers Hyderabad','Delhi Captials','Rising Pune Supergiant','Rising Pune Supergiant'],inplace=True)

encode = {'team1': {'Mumbai Indians':1,'Kolkata Knight Riders':2,'Royal Challengers Bangalore':3,'Delhi Captials':4,'Chennai Super Kings':5,'Rajasthan Royals':6,'Gujarat Lions':7,'Kings XI Punjab':8,'Sunrisers Hyderabad':9,'Rising Pune Supergiant':10,'Kochi Tuskers Kerala':11,},
          'team2': {'Mumbai Indians':1,'Kolkata Knight Riders':2,'Royal Challengers Bangalore':3,'Delhi Captials':4,'Chennai Super Kings':5,'Rajasthan Royals':6,'Gujarat Lions':7,'Kings XI Punjab':8,'Sunrisers Hyderabad':9,'Rising Pune Supergiant':10,'Kochi Tuskers Kerala':11,},
          'toss_winner': {'Mumbai Indians':1,'Kolkata Knight Riders':2,'Royal Challengers Bangalore':3,'Delhi Captials':4,'Chennai Super Kings':5,'Rajasthan Royals':6,'Gujarat Lions':7,'Kings XI Punjab':8,'Sunrisers Hyderabad':9,'Rising Pune Supergiant':10,'Kochi Tuskers Kerala':11,},
          'winner': {'Mumbai Indians':1,'Kolkata Knight Riders':2,'Royal Challengers Bangalore':3,'Delhi Captials':4,'Chennai Super Kings':5,'Rajasthan Royals':6,'Gujarat Lions':7,'Kings XI Punjab':8,'Sunrisers Hyderabad':9,'Rising Pune Supergiant':10,'Kochi Tuskers Kerala':11,'Draw':12}}
Matches.replace(encode, inplace=True)
Matches.head(100)
# Out:
#      id  season            city       date  team1  team2  toss_winner  \
# 0     1    2008       Bangalore  4/18/2008      2      3            3
# 1     2    2008      Chandigarh  4/19/2008      5      8            5
# 2     3    2008           Delhi  4/19/2008      6      4            6
# 3     4    2008          Mumbai  4/20/2008      1      3            1
# 4     5    2008         Kolkata  4/20/2008      9      2            9
# 5     6    2008          Jaipur  4/21/2008      8      6            8
# 6     7    2008       Hyderabad  4/22/2008      9      4            9
# 7     8    2008         Chennai  4/23/2008      5      1            1
# 8     9    2008       Hyderabad  4/24/2008      9      6            6
# 9    10    2008      Chandigarh  4/25/2008      8      1            1
# 10   11    2008       Bangalore  4/26/2008      3      6            6
# 11   12    2008         Chennai  4/26/2008      2      5            2
# ...

# %%
Matches.describe()
# Out:
#                id       season       team1       team2  toss_winner  \
# count  577.000000   577.000000  577.000000  577.000000   577.000000
# mean   289.000000  2012.029463    5.171577    5.031196     5.098787
# std    166.709828     2.486247    2.936839    2.861210     2.919454
# min      1.000000  2008.000000    1.000000    1.000000     1.000000
# 25%    145.000000  2010.000000    3.000000    3.000000     3.000000
# 50%    289.000000  2012.000000    5.000000    5.000000     5.000000
# 75%    433.000000  2014.000000    8.000000    8.000000     8.000000
# max    577.000000  2016.000000   11.000000   11.000000    11.000000
#
#        dl_applied      winner  win_by_runs  win_by_wickets
# count  577.000000  577.000000   577.000000      577.000000
# mean     0.025997    4.902946    13.715771        3.363951
# std      0.159263    2.851828    23.619282        3.416049
# min      0.000000    1.000000     0.000000        0.000000
# ...

# %%
CorRelation=Matches.corr()
CorRelation
# Out:
#                       id    season     team1     team2  toss_winner  \
# id              1.000000  0.992806  0.040718  0.002719     0.001263
# season          0.992806  1.000000  0.047098  0.005484     0.002469
# team1           0.040718  0.047098  1.000000 -0.115925     0.426886
# team2           0.002719  0.005484 -0.115925  1.000000     0.464981
# toss_winner     0.001263  0.002469  0.426886  0.464981     1.000000
# dl_applied      0.017197  0.015600  0.034989  0.043936     0.065411
# winner          0.016761  0.019992  0.407447  0.433140     0.378996
# win_by_runs    -0.014813 -0.018098 -0.115627  0.068415    -0.013238
# win_by_wickets -0.012804 -0.005966  0.064716 -0.085535     0.036601
#
#                 dl_applied    winner  win_by_runs  win_by_wickets
# id                0.017197  0.016761    -0.014813       -0.012804
# season            0.015600  0.019992    -0.018098       -0.005966
# team1             0.034989  0.407447    -0.115627        0.064716
# ...

# %%
Matches[pd.isnull(Matches['city'])]
# Out:
#       id  season city       date  team1  team2  toss_winner toss_decision  \
# 402  403    2014  NaN  4/19/2014      1      3            3         field
# 403  404    2014  NaN  4/19/2014      2      4            2           bat
# 407  408    2014  NaN  4/23/2014      5      6            6         field
# 409  410    2014  NaN  4/25/2014      9      4            9           bat
# 410  411    2014  NaN  4/25/2014      1      5            1           bat
# 415  416    2014  NaN  4/28/2014      3      8            8         field
# 417  418    2014  NaN  4/30/2014      9      1            1         field
#
#      result  dl_applied  winner  win_by_runs  win_by_wickets player_of_match  \
# 402  normal           0       3            0               7        PA Patel
# 403  normal           0       4            0               4       JP Duminy
# 407  normal           0       5            7               0       RA Jadeja
# ...

# %%
Matches['city'].fillna('Dubai',inplace=True)

# %%
Matches.iloc[401:418]
# Out:
#       id  season       city       date  team1  team2  toss_winner  \
# 401  402    2014  Abu Dhabi  4/18/2014      9      6            6
# 402  403    2014      Dubai  4/19/2014      1      3            3
# 403  404    2014      Dubai  4/19/2014      2      4            2
# 404  405    2014    Sharjah  4/20/2014      6      8            8
# 405  406    2014  Abu Dhabi  4/21/2014      5      4            5
# 406  407    2014    Sharjah  4/22/2014      8      9            9
# 407  408    2014      Dubai  4/23/2014      5      6            6
# 408  409    2014    Sharjah  4/24/2014      2      3            3
# 409  410    2014      Dubai  4/25/2014      9      4            9
# 410  411    2014      Dubai  4/25/2014      1      5            1
# 411  412    2014  Abu Dhabi  4/26/2014      3      6            6
# 412  413    2014  Abu Dhabi  4/26/2014      8      2            2
# 413  414    2014    Sharjah  4/27/2014      1      4            1
# ...

# %%
matches = Matches[['team1','team2','city','toss_decision','toss_winner','venue','winner']]
matches.head(2)
# Out:
#    team1  team2        city toss_decision  toss_winner  \
# 0      2      3   Bangalore         field            3
# 1      5      8  Chandigarh           bat            5
#
#                                         venue  winner
# 0                       M Chinnaswamy Stadium       2
# 1  Punjab Cricket Association Stadium, Mohali       5

# %%
Teams=encode['winner']

# %%
TimesTeamsWonMatches=matches['winner'].value_counts(sort=True)
print('No of match winners by each team')
for idx, val in TimesTeamsWonMatches.iteritems():
   print('{} -> {}'.format(list(Teams.keys())[list(Teams.values()).index(idx)],val))
# Out:
# No of match winners by each team
# Mumbai Indians -> 80
# Chennai Super Kings -> 79
# Royal Challengers Bangalore -> 70
# Kolkata Knight Riders -> 68
# Sunrisers Hyderabad -> 63
# Kings XI Punjab -> 63
# Rajasthan Royals -> 63
# Delhi Captials -> 56
# Rising Pune Supergiant -> 17
# Gujarat Lions -> 9
# Kochi Tuskers Kerala -> 6
# Draw -> 3

# %%
MatchWinners = plt.figure(figsize=(10,5))
ax1 = MatchWinners.add_subplot(111)
ax1.set_xlabel('Match_winner')
ax1.set_ylabel('Count of Match winners')
ax1.set_title("Match winners")
TimesTeamsWonMatches.plot(kind='bar')
print(Teams)
# Out:
# {'Mumbai Indians': 1, 'Kolkata Knight Riders': 2, 'Royal Challengers Bangalore': 3, 'Delhi Captials': 4, 'Chennai Super Kings': 5, 'Rajasthan Royals': 6, 'Gujarat Lions': 7, 'Kings XI Punjab': 8, 'Sunrisers Hyderabad': 9, 'Rising Pune Supergiant': 10, 'Kochi Tuskers Kerala': 11, 'Draw': 12}

# %%
TimesTeamsWonToss=matches['toss_winner'].value_counts(sort=True)
print('No of toss winners by each team')
for idx, val in TimesTeamsWonToss.iteritems():
   print('{} -> {}'.format(list(Teams.keys())[list(Teams.values()).index(idx)],val))
# Out:
# No of toss winners by each team
# Mumbai Indians -> 74
# Sunrisers Hyderabad -> 73
# Kolkata Knight Riders -> 69
# Chennai Super Kings -> 66
# Kings XI Punjab -> 64
# Delhi Captials -> 64
# Rajasthan Royals -> 63
# Royal Challengers Bangalore -> 61
# Rising Pune Supergiant -> 27
# Kochi Tuskers Kerala -> 8
# Gujarat Lions -> 8

# %%
TossWinners = plt.figure(figsize=(10,5))
ax1 = TossWinners.add_subplot(111)
ax1.set_xlabel('toss_winner')
ax1.set_ylabel('Count of toss winners')
ax1.set_title("toss winners")
TimesTeamsWonToss.plot(kind='bar')
print(Teams)
# Out:
# {'Mumbai Indians': 1, 'Kolkata Knight Riders': 2, 'Royal Challengers Bangalore': 3, 'Delhi Captials': 4, 'Chennai Super Kings': 5, 'Rajasthan Royals': 6, 'Gujarat Lions': 7, 'Kings XI Punjab': 8, 'Sunrisers Hyderabad': 9, 'Rising Pune Supergiant': 10, 'Kochi Tuskers Kerala': 11, 'Draw': 12}

# %%
from sklearn.preprocessing import LabelEncoder as le
matches["Venue"] = le().fit_transform(matches["venue"])
matches[["Venue","venue"]].head()
# Out:
# C:\Users\saide\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    Venue                                       venue
# 0     14                       M Chinnaswamy Stadium
# 1     22  Punjab Cricket Association Stadium, Mohali
# 2      8                            Feroz Shah Kotla
# 3     34                            Wankhede Stadium
# 4      7                                Eden Gardens

# %%
matches["City"] = le().fit_transform(matches["city"])
matches[["City","city"]].head()
# Out:
# C:\Users\saide\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    City        city
# 0     2   Bangalore
# 1     6  Chandigarh
# 2     9       Delhi
# 3    22      Mumbai
# 4    21     Kolkata

# %%
matches["TossDecision"] = le().fit_transform(matches["toss_decision"])
matches[["TossDecision","toss_decision"]].head()
# Out:
# C:\Users\saide\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    TossDecision toss_decision
# 0             1         field
# 1             0           bat
# 2             0           bat
# 3             0           bat
# 4             0           bat

# %%
#Import models from scikit learn module:
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn import metrics

#Generic function for making a classification model and accessing performance:
def classification_model(model, data, predictors, outcome):
      model.fit(data[predictors],data[outcome])
      predictions = model.predict(data[predictors])
      print(predictions)
      accuracy = metrics.accuracy_score(predictions,data[outcome])
      print('Accuracy : %s' % '{0:.2%}'.format(accuracy))

# %%
#LOGISTIC REGRESSION
outcome_var=['winner']
predictor_var = ['team1', 'team2', 'Venue', 'toss_winner','City','TossDecision']
model =LogisticRegression()
classification_model(model, matches,predictor_var,outcome_var)
# Out:
# [3 5 5 1 2 6 6 3 8 8 3 5 2 5 5 1 3 9 1 5 6 6 1 5 3 9 2 3 2 8 3 8 5 6 5 2 1
#  8 9 1 5 1 3 2 3 2 1 5 8 3 5 3 2 1 6 1 6 2 3 5 8 5 1 8 6 5 3 5 5 1 9 9 1 6
#  1 5 8 6 2 5 6 2 1 1 9 9 5 6 3 6 2 9 2 1 1 9 1 6 9 5 1 3 1 3 9 5 6 1 2 5 1
#  8 6 1 8 2 2 8 2 9 8 5 2 3 3 5 9 3 2 9 8 2 3 8 2 6 5 3 6 2 5 2 5 5 5 6 5 2
#  5 5 6 3 6 2 3 5 6 3 5 1 6 2 5 1 5 9 3 2 8 9 1 2 9 2 2 5 8 9 2 9 5 5 3 8 9
#  8 1 1 5 9 9 2 9 9 6 2 8 1 1 9 3 8 9 3 9 9 3 1 3 9 2 8 5 1 9 3 5 5 8 8 3 2
#  1 9 9 6 9 8 1 5 9 3 1 8 9 9 5 8 2 1 9 5 3 1 1 1 1 5 3 2 6 6 3 9 1 9 2 3 3
#  1 5 8 2 9 9 2 5 1 9 9 6 6 9 8 5 8 1 8 1 6 3 9 2 5 2 5 6 5 9 6 3 5 5 5 8 1
#  8 5 6 9 1 6 6 1 3 9 9 3 2 5 1 9 3 9 8 5 8 1 1 3 3 5 2 3 9 5 5 9 5 1 1 8 3
#  9 5 5 3 5 8 9 8 3 9 1 5 9 2 3 5 8 5 3 8 1 9 2 9 1 3 9 1 1 9 5 1 5 5 2 5 3
#  1 9 5 5 1 9 8 5 3 1 8 1 6 9 1 2 5 1 3 9 2 6 3 5 2 9 2 2 1 1 8 8 1 5 9 6 9
#  9 1 9 5 3 8 1 6 3 6 2 1 1 3 8 3 3 1 5 9 8 8 9 1 2 5 6 2 3 9 2 8 2 6 5 9 5
# ...

# %%
## RANDOM FOREST CLASSIFIER
outcome_var=['winner']
predictor_var = ['team1', 'team2', 'Venue', 'toss_winner','City','TossDecision']
model =RandomForestClassifier(n_estimators=100)
classification_model(model, matches,predictor_var,outcome_var)
# Out:
# C:\Users\saide\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if __name__ == '__main__':
# [ 3  5  4  1  2  6  4  1  6  8  6  5  1  8  5  1  3  8  6  4  3  8  1  6
#   3  9  1  5  2  6  1  5  2  6  8  2  1  8  4  1  8  3  1  5  3  6  8  5
#   9  1  5  9  2  6  5  6  5  6  1  3  4  9  5  2  9  4  6  8  9  4  8  9
#   1  6  3  8  4  5  1  8  6  5  8  3  5  6  4  9  6  5  4  8  5  1  4  9
#   3  1  4  3  6  8  5  9  8  4  2  3  2  5  4  3  9  3  9  2  1  4  2  9
#   6  3  2  1  3  5  9  6  3  9  8  1  3  6  1  6  2  4  6  1  2  1  5  4
#   2  3  5  1  8  4  6  5  6  2  9  1  9  3  8  6  9  1  5  3  4  9  1  2
#   5  9  1  1  5  3  5  2  6  3  1 10  2  6  1  8 10  9  6 11  5  8  4  2
#  11  9  1 11  8  5  3  8  1  6  5  3  5  9  2  6  3  4  2  6  5  1 11  2
# ...

# %%
Testing=pd.read_csv("C:\\Users\\saide\\Desktop\\Capstone Project\\ipldata\\matches(2017).csv")

# %%
Testing
# Out:
#     id  season        city        date                        team1  \
# 0    1    2017   Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1    2    2017        Pune  2017-04-06               Mumbai Indians
# 2    3    2017      Rajkot  2017-04-07                Gujarat Lions
# 3    4    2017      Indore  2017-04-08       Rising Pune Supergiant
# 4    5    2017   Bangalore  2017-04-08  Royal Challengers Bangalore
# 5    6    2017   Hyderabad  2017-04-09                Gujarat Lions
# 6    7    2017      Mumbai  2017-04-09        Kolkata Knight Riders
# 7    8    2017      Indore  2017-04-10  Royal Challengers Bangalore
# 8    9    2017        Pune  2017-04-11             Delhi Daredevils
# 9   10    2017      Mumbai  2017-04-12          Sunrisers Hyderabad
# 10  11    2017     Kolkata  2017-04-13              Kings XI Punjab
# 11  12    2017   Bangalore  2017-04-14  Royal Challengers Bangalore
# 12  13    2017      Rajkot  2017-04-14       Rising Pune Supergiant
# ...

# %%
Testing.replace(['Deccan Chargers','Delhi Daredevils','Pune Warriors','Rising Pune Supergiants'],['Sunrisers Hyderabad','Delhi Captials','Rising Pune Supergiant','Rising Pune Supergiant'],inplace=True)

encode = {'team1': {'Mumbai Indians':1,'Kolkata Knight Riders':2,'Royal Challengers Bangalore':3,'Delhi Captials':4,'Chennai Super Kings':5,'Rajasthan Royals':6,'Gujarat Lions':7,'Kings XI Punjab':8,'Sunrisers Hyderabad':9,'Rising Pune Supergiant':10,'Kochi Tuskers Kerala':11,},
          'team2': {'Mumbai Indians':1,'Kolkata Knight Riders':2,'Royal Challengers Bangalore':3,'Delhi Captials':4,'Chennai Super Kings':5,'Rajasthan Royals':6,'Gujarat Lions':7,'Kings XI Punjab':8,'Sunrisers Hyderabad':9,'Rising Pune Supergiant':10,'Kochi Tuskers Kerala':11,},
          'toss_winner': {'Mumbai Indians':1,'Kolkata Knight Riders':2,'Royal Challengers Bangalore':3,'Delhi Captials':4,'Chennai Super Kings':5,'Rajasthan Royals':6,'Gujarat Lions':7,'Kings XI Punjab':8,'Sunrisers Hyderabad':9,'Rising Pune Supergiant':10,'Kochi Tuskers Kerala':11,},
          'winner': {'Mumbai Indians':1,'Kolkata Knight Riders':2,'Royal Challengers Bangalore':3,'Delhi Captials':4,'Chennai Super Kings':5,'Rajasthan Royals':6,'Gujarat Lions':7,'Kings XI Punjab':8,'Sunrisers Hyderabad':9,'Rising Pune Supergiant':10,'Kochi Tuskers Kerala':11,'Draw':12}}
Testing.replace(encode, inplace=True)
Testing
# Out:
#     id  season        city        date  team1  team2  toss_winner  \
# 0    1    2017   Hyderabad  2017-04-05      9      3            3
# 1    2    2017        Pune  2017-04-06      1     10           10
# 2    3    2017      Rajkot  2017-04-07      7      2            2
# 3    4    2017      Indore  2017-04-08     10      8            8
# 4    5    2017   Bangalore  2017-04-08      3      4            3
# 5    6    2017   Hyderabad  2017-04-09      7      9            9
# 6    7    2017      Mumbai  2017-04-09      2      1            1
# 7    8    2017      Indore  2017-04-10      3      8            3
# 8    9    2017        Pune  2017-04-11      4     10           10
# 9   10    2017      Mumbai  2017-04-12      9      1            1
# 10  11    2017     Kolkata  2017-04-13      8      2            2
# 11  12    2017   Bangalore  2017-04-14      3      1            1
# 12  13    2017      Rajkot  2017-04-14     10      7            7
# ...

# %%
Testing=Testing.drop(['winner','date','id','season','result','dl_applied','win_by_runs','win_by_wickets','player_of_match'],axis=1,inplace=False)

# %%
Testing["TossDecision"] = le().fit_transform(Testing["toss_decision"])
Testing[["TossDecision","toss_decision"]].head()
# Out:
#    TossDecision toss_decision
# 0             1         field
# 1             1         field
# 2             1         field
# 3             1         field
# 4             0           bat

# %%
Testing["Venue"] = le().fit_transform(Testing["venue"])
Testing[["Venue","venue"]]
# Out:
#     Venue                                              venue
# 0       7          Rajiv Gandhi International Stadium, Uppal
# 1       5            Maharashtra Cricket Association Stadium
# 2       8             Saurashtra Cricket Association Stadium
# 3       3                             Holkar Cricket Stadium
# 4       4                              M Chinnaswamy Stadium
# 5       7          Rajiv Gandhi International Stadium, Uppal
# 6       9                                   Wankhede Stadium
# 7       3                             Holkar Cricket Stadium
# 8       5            Maharashtra Cricket Association Stadium
# 9       9                                   Wankhede Stadium
# 10      0                                       Eden Gardens
# 11      4                              M Chinnaswamy Stadium
# 12      8             Saurashtra Cricket Association Stadium
# 13      0                                       Eden Gardens
# ...

# %%
Testing["City"] = le().fit_transform(Testing["city"])
Testing[["City","city"]]
# Out:
#     City        city
# 0      3   Hyderabad
# 1      8        Pune
# 2      9      Rajkot
# 3      4      Indore
# 4      0   Bangalore
# 5      3   Hyderabad
# 6      7      Mumbai
# 7      4      Indore
# 8      8        Pune
# 9      7      Mumbai
# 10     6     Kolkata
# 11     0   Bangalore
# 12     9      Rajkot
# 13     6     Kolkata
# 14     2       Delhi
# 15     7      Mumbai
# 16     0   Bangalore
# 17     2       Delhi
# 18     3   Hyderabad
# 19     9      Rajkot
# 20     3   Hyderabad
# 21     4      Indore
# 22     6     Kolkata
# 23     7      Mumbai
# 24     8        Pune
# 25     9      Rajkot
# 26     6     Kolkata
# 27     7      Mumbai
# 28     8        Pune
# 29     0   Bangalore
# 30     6     Kolkata
# 31     1  Chandigarh
# 32     8        Pune
# 33     9      Rajkot
# 34     1  Chandigarh
# 35     3   Hyderabad
# 36     7      Mumbai
# 37     8        Pune
# 38     2       Delhi
# 39     6     Kolkata
# 40     2       Delhi
# 41     0   Bangalore
# ...

# %%
Testing.head()
# Out:
#         city  team1  team2  toss_winner toss_decision  \
# 0  Hyderabad      9      3            3         field
# 1       Pune      1     10           10         field
# 2     Rajkot      7      2            2         field
# 3     Indore     10      8            8         field
# 4  Bangalore      3      4            3           bat
#
#                                        venue  TossDecision  Venue  City
# 0  Rajiv Gandhi International Stadium, Uppal             1      7     3
# 1    Maharashtra Cricket Association Stadium             1      5     8
# 2     Saurashtra Cricket Association Stadium             1      8     9
# 3                     Holkar Cricket Stadium             1      3     4
# 4                      M Chinnaswamy Stadium             0      4     0

# %%
Test=Testing.drop(['city','venue','toss_decision'],axis=1,inplace=False)
Test.head()
# Out:
#    team1  team2  toss_winner  TossDecision  Venue  City
# 0      9      3            3             1      7     3
# 1      1     10           10             1      5     8
# 2      7      2            2             1      8     9
# 3     10      8            8             1      3     4
# 4      3      4            3             0      4     0

# %%
print(Teams)
# Out:
# {'Mumbai Indians': 1, 'Kolkata Knight Riders': 2, 'Royal Challengers Bangalore': 3, 'Delhi Captials': 4, 'Chennai Super Kings': 5, 'Rajasthan Royals': 6, 'Gujarat Lions': 7, 'Kings XI Punjab': 8, 'Sunrisers Hyderabad': 9, 'Rising Pune Supergiant': 10, 'Kochi Tuskers Kerala': 11, 'Draw': 12}

# %%
Outcome=model.predict(Test)
Outcome
# Out:
# array([3, 1, 2, 8, 4, 9, 1, 8, 9, 9, 2, 1, 8, 9, 8, 1, 3, 1, 8, 3, 4, 1,
#        1, 4, 9, 8, 3, 9, 2, 1, 1, 8, 3, 1, 8, 2, 1, 9, 4, 1, 4, 8, 9, 4,
#        1, 8, 1, 2, 4, 8, 4, 9, 1, 8, 4, 9, 2, 1, 1], dtype=int64)

# %%
predicted_winner=[]
for i in Outcome:
    predicted_winner.append(list(Teams.keys())[list(Teams.values()).index(i)])

# %%
ipl=pd.read_csv('C:\\Users\\saide\\Desktop\\Capstone Project\\ipldata\\matches(2017).csv')
I=0
P=0
total=len(ipl['winner'])
for i in ipl['winner']:
    if i==predicted_winner[P]:
        I=I+1
    P=P+1  
print(I)
print("Accuracy of our prediction of recent IPL is ", I/total)
# Out:
# 22
# Accuracy of our prediction of recent IPL is  0.3728813559322034

# %%
predicted_winner
# Out:
# ['Royal Challengers Bangalore',
#  'Mumbai Indians',
#  'Kolkata Knight Riders',
#  'Kings XI Punjab',
#  'Delhi Captials',
#  'Sunrisers Hyderabad',
#  'Mumbai Indians',
#  'Kings XI Punjab',
#  'Sunrisers Hyderabad',
#  'Sunrisers Hyderabad',
#  'Kolkata Knight Riders',
#  'Mumbai Indians',
#  'Kings XI Punjab',
#  'Sunrisers Hyderabad',
#  'Kings XI Punjab',
#  'Mumbai Indians',
#  'Royal Challengers Bangalore',
#  'Mumbai Indians',
#  'Kings XI Punjab',
#  'Royal Challengers Bangalore',
#  'Delhi Captials',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Delhi Captials',
#  'Sunrisers Hyderabad',
#  'Kings XI Punjab',
#  'Royal Challengers Bangalore',
#  'Sunrisers Hyderabad',
#  'Kolkata Knight Riders',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Kings XI Punjab',
#  'Royal Challengers Bangalore',
#  'Mumbai Indians',
#  'Kings XI Punjab',
#  'Kolkata Knight Riders',
#  'Mumbai Indians',
#  'Sunrisers Hyderabad',
#  'Delhi Captials',
#  'Mumbai Indians',
#  'Delhi Captials',
# ...

# %%
Input = pd.Series(model.feature_importances_, index=predictor_var).sort_values(ascending=False)
print()
print(Input)
# Out:
# team2           0.258198
# team1           0.209037
# Venue           0.174782
# City            0.162989
# toss_winner     0.159595
# TossDecision    0.035399
# dtype: float64

# %%
PredictedOutcome = pd.DataFrame()
PredictedOutcome['team1'] = ipl['team1']
PredictedOutcome['team2'] = ipl['team2']
PredictedOutcome['venue'] = ipl['venue']
PredictedOutcome['toss_winner'] =ipl['toss_winner']
PredictedOutcome['city'] = ipl['city']
PredictedOutcome['toss_decision'] = ipl['toss_decision']
PredictedOutcome['date of match']=ipl['date']
PredictedOutcome['actual_winner']=ipl["winner"]
PredictedOutcome['Predicted_winner'] = predicted_winner
PredictedOutcome.to_csv('ipl2.csv',index=False)

# %%
PredictedOutcome[PredictedOutcome.columns[7:9]]
# Out:
#                   actual_winner             Predicted_winner
# 0           Sunrisers Hyderabad  Royal Challengers Bangalore
# 1        Rising Pune Supergiant               Mumbai Indians
# 2         Kolkata Knight Riders        Kolkata Knight Riders
# 3               Kings XI Punjab              Kings XI Punjab
# 4   Royal Challengers Bangalore               Delhi Captials
# 5           Sunrisers Hyderabad          Sunrisers Hyderabad
# 6                Mumbai Indians               Mumbai Indians
# 7               Kings XI Punjab              Kings XI Punjab
# 8              Delhi Daredevils          Sunrisers Hyderabad
# 9                Mumbai Indians          Sunrisers Hyderabad
# 10        Kolkata Knight Riders        Kolkata Knight Riders
# 11               Mumbai Indians               Mumbai Indians
# 12                Gujarat Lions              Kings XI Punjab
# 13        Kolkata Knight Riders          Sunrisers Hyderabad
# ...
